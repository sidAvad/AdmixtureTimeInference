# %% [markdown]
# # Diagnostics for AdmixtureTimeInference

# %%
# %cd ~/cbsu_rsync/AdmixtureTimeInference/
# Out:
# /Users/Siddharth/cbsu_rsync/AdmixtureTimeInference

# %%
#Importing results from Output of AdmixtureTimeInference Jupyter Notebook
import pandas as pd
results_diagnose = pd.read_csv("/Users/Siddharth/cbsu_rsync/AdmixtureTimeInference/Results/JupyterNotebookOutput/results_diagnose.txt")

# %%
import importlib
import ast
importlib.reload(dv)
from AdmixtureTimeInference import dataViz as dv
results_diagnose[['rhs1_check','rhs0_check']]= results_diagnose.apply( lambda x:pd.Series(dv.compute_markovWF(ast.literal_eval(x['p1_inf'])[0],ast.literal_eval(x['p2_inf'])[0],x['t1'],x['t2'])),axis=1)
# Out:
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# 1.0 0.0 nan nan
# ...

# %%
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 2000)

results_diagnose
# Out:
#       t  admixtype        t1        t2  \
# 0     2          1       NaN       NaN
# 1     2          1       NaN       NaN
# 2     2          1       NaN       NaN
# 3     2          1       NaN       NaN
# 4     2          1       NaN       NaN
# 5     2          1       NaN       NaN
# 6     2          1       NaN       NaN
# 7     2          1       NaN       NaN
# 8     2          1       NaN       NaN
# 9     2          1       NaN       NaN
# 10    2          1       NaN       NaN
# 11    2          1       NaN       NaN
# 12    2          1       NaN       NaN
# 13    2          1       NaN       NaN
# 14    2          1       NaN       NaN
# 15    2          1       NaN       NaN
# 16    2          1       NaN       NaN
# 17    2          1       NaN       NaN
# 18    2          1       NaN       NaN
# 19    2          1       NaN       NaN
# 20    2          1       NaN       NaN
# 21    2          1       NaN       NaN
# 22    2          1       NaN       NaN
# ...

# %%
#Counting entries for each admixtype (t=3)
for typ in range(1,17):
    print(len(results_diagnose[(results_diagnose.t==3) & (results_diagnose.admixtype==typ)]))
# Out:
# 100
# 100
# 100
# 99
# 100
# 99
# 100
# 99
# 100
# 99
# 100
# 100
# 100
# 98
# 97
# 100
